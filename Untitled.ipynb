# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import os

# %%
#Loading Data

companies = pd.DataFrame.from_csv('companies.csv',0,';')
prices = pd.DataFrame.from_csv('prices.csv',0,';')
sectors = pd.DataFrame.from_csv('sectors.csv',0,';')

names = companies.reset_index(drop=False, inplace=False)
names = names['NAME']
names.to_csv('names.csv')
#companies
#prices
companies.reset_index(drop=False,inplace=True)
prices.reset_index(drop=False,inplace=True)
# print('Dimensions of the Company Dataset'+ str(companies.shape))
# print('')
# print(list(companies))
# print('-------------------------------------------------------------------------')
# print('Dimensions of the Prices Dataset'+ str(prices.shape))
# print('')
# print(list(prices))
# print('-------------------------------------------------------------------------')
# print('Dimensions of the Sector Dataset'+ str(sectors.shape))
# print('')
# print(list(sectors))
print(companies)
print(prices)
# Out:
#                        NAME SYMBOL  IS_PART_OF_SMI  SECTOR     ISIN_CODE  \
# 0                  NESTLE N   NESN               1    2400  CH0038863350
# 1             JULIUS BAER N   BAER               1    4800  CH0102484968
# 2                  ARYZTA N   ARYN               0    2400  CH0043238366
# 3              SCHINDLER PS   SCHP               0    1200  CH0024638196
# 4           LAFARGEHOLCIM N    LHN               1    1100  CH0012214059
# 5                  ADECCO N   ADEN               1    3200  CH0012138605
# 6                SWISS RE N   SREN               1    4800  CH0126881561
# 7                CLARIANT N    CLN               0    2200  CH0012142631
# 8                 BALOISE N   BALN               0    4800  CH0012410517
# 9                CS GROUP N   CSGN               1    4800  CH0012138530
# 10               NOVARTIS N   NOVN               1    2300  CH0012005267
# 11               GIVAUDAN N   GIVN               1    2400  CH0010645932
# 12                  LONZA N   LONN               1    2300  CH0013841017
# 13               SWISSCOM N   SCMN               1    4900  CH0008742519
# 14                    SGS N   SGSN               1    3200  CH0002497458
# 15                 SONOVA N   SOON               0    2300  CH0012549785
# 16                ABB LTD N   ABBN               1    1200  CH0012221716
# 17           SWATCH GROUP I    UHR               1    1400  CH0012255151
# 18                  DUFRY N   DUFN               0    3500  CH0023405456
# 19              UBS GROUP N   UBSG               1    4800  CH0244767585
# 20                 ROCHE GS    ROG               1    2300  CH0012032048
# 21       ZURICH INSURANCE N   ZURN               1    4800  CH0011075394
# 22               LOGITECH N   LOGN               0    1300  CH0025751329
# 23         PARTNERS GROUP N   PGHN               0    4800  CH0024608827
# 24              RICHEMONT N    CFR               1    1400  CH0210483332
# 25  SWISS LIFE HOLDING AG N   SLHN               1    4800  CH0014852781
# 26                   SIKA I    SIK               1    2200  CH0000587979
# 27                  VIFOR N   VIFN               0    2300  CH0364749348
# 28                GEBERIT N   GEBN               1    1200  CH0030170408
# 29       KUEHNE+NAGEL INT N   KNIN               0    4600  CH0025238863
#
#     INDUSTRY  MARKET_CAP_MIO  SMI_WEIGHT
# 0          5       229241.71       22.19
# 1         10        11191.37        1.06
# 2         10         2810.00         NaN
# 3         10        23570.00         NaN
# 4         35        30052.32        3.07
# 5         35        11256.94        1.06
# 6         60        27644.12        2.69
# 7         10         8190.00         NaN
# 8         60         7590.00         NaN
# 9          5        34355.35        3.19
# 10         5       190207.98       18.36
# 11        35        17343.00        1.57
# 12        20        17393.59        1.52
# 13         5        22499.14        2.18
# 14         5        15293.62        1.44
# 15        25        11310.00         NaN
# 16        55        46159.88        4.21
# 17        45        18629.78        1.79
# 18        40             NaN         NaN
# 19         5        56606.27        5.41
# 20         5       183041.98       18.31
# 21        60        38574.77        3.85
# 22        45         6080.00         NaN
# 23        45        17830.00         NaN
# 24        45        40602.73        4.18
# 25        65         9567.77        0.98
# 26        40        13499.95        1.46
# 27         5         7550.00         NaN
# 28        30        14976.44        1.47
# 29        25        21270.00         NaN
#            ISIN_CODE    PRICE   VOL       TIMESTAMP
# 0       CH0012255151   401.00     1  20171011090058
# 1       CH0012255151   401.00     1  20171011090058
# 2       CH0012255151   401.00     3  20171011090058
# 3       CH0012255151   401.00     3  20171011090058
# 4       CH0012255151   401.00    20  20171011090058
# 5       CH0012255151   401.00     1  20171011090058
# 6       CH0012255151   401.00     1  20171011090058
# 7       CH0012255151   401.00     1  20171011090058
# 8       CH0012255151   401.00    17  20171011090058
# 9       CH0012255151   401.00     3  20171011090058
# 10      CH0012255151   401.00    33  20171011090058
# 11      CH0012255151   401.00     7  20171011090058
# 12      CH0012255151   401.00     2  20171011090058
# 13      CH0012255151   401.00    23  20171011090058
# 14      CH0012255151   401.00    11  20171011090058
# 15      CH0012255151   401.00    17  20171011090058
# 16      CH0012255151   401.00    14  20171011090058
# 17      CH0012255151   401.00    35  20171011090058
# 18      CH0012255151   401.00    15  20171011090058
# 19      CH0012255151   401.00    14  20171011090058
# 20      CH0012255151   401.00    29  20171011090058
# 21      CH0012255151   401.00    21  20171011090058
# 22      CH0012255151   401.00     4  20171011090058
# 23      CH0012255151   401.00     6  20171011090058
# 24      CH0014852781   341.30     4  20171011090058
# 25      CH0014852781   341.30     6  20171011090058
# 26      CH0014852781   341.30    20  20171011090058
# 27      CH0014852781   341.30     1  20171011090058
# 28      CH0014852781   341.30     1  20171011090058
# 29      CH0014852781   341.30    25  20171011090058
# ...              ...      ...   ...             ...
# 526286  CH0008742519   499.20    50  20171010171235
# 526287  CH0008742519   499.20    50  20171010171235
# 526288  CH0008742519   499.20    50  20171010171235
# 526289  CH0364749348   116.65   114  20171010171235
# 526290  CH0012142631    23.80   384  20171010171236
# 526291  CH0012142631    23.80   872  20171010171236
# 526292  CH0012142631    23.80   897  20171010171236
# 526293  CH0012142631    23.80   630  20171010171236
# 526294  CH0012142631    23.80  1172  20171010171236
# 526295  CH0012142631    23.80   900  20171010171236
# 526296  CH0012142631    23.80    46  20171010171236
# 526297  CH0012142631    23.80   333  20171010171237
# 526298  CH0012142631    23.80   747  20171010171237
# 526299  CH0024638196   217.90    70  20171010171238
# 526300  CH0024638196   217.90    44  20171010171238
# 526301  CH0024638196   217.90    13  20171010171238
# 526302  CH0025751329    34.94   500  20171010171238
# 526303  CH0043238366    31.07   128  20171010171429
# 526304  CH0012005267    83.45   400  20171010171430
# 526305  CH0012005267    83.45    33  20171010171430
# 526306  CH0013841017   261.50     5  20171010171430
# 526307  CH0013841017   261.50    11  20171010171430
# 526308  CH0013841017   261.50     3  20171010171430
# 526309  CH0013841017   261.50     2  20171010171430
# 526310  CH0024638196   217.90    21  20171010171434
# 526311  CH0024638196   217.90    10  20171010171434
# 526312  CH0024638196   217.90     5  20171010171434
# 526313  CH0002497458  2328.00     3  20171010171435
# 526314  CH0002497458  2328.00     4  20171010171435
# 526315  CH0002497458  2328.00    15  20171010171435
#
# [526316 rows x 4 columns]

# %%
#Combining the Data into dictionaries

mess = pd.merge(companies, prices, on='ISIN_CODE', how='outer')
mess.fillna(value='unknown',inplace=True)
mess.to_csv('companies_prices.csv')
df = mess.set_index('NAME')

# %%
df_split = {x: df.loc[x]  for x in df.index.unique()}

# %%
path = 'company_dataframes/'
for i in df.index.unique():
    filename = str(i)+'.csv'
    df_split[i].to_csv(path + filename)

# %%
filelist = os.listdir(path)
f=0


file = 'NESTLE N.csv'
crazy = pd.DataFrame.from_csv(file,0,',')

pd.concat([crazy, pd.DataFrame(columns = [ 'YEAR', 'DAY','TIME'])])
crazy['YEAR'] = crazy['TIMESTAMP'].astype(str).str[0:4]
crazy['DAY'] = crazy['TIMESTAMP'].astype(str).str[6:8]
crazy['TIME'] = crazy['TIMESTAMP'].astype(str).str[8:14]




# crazy.sort_values(by=['TIMESTAMP'],ascending=False)
# crazy['TIMESTAMP']=crazy['TIMESTAMP'].astype(str)
# crazy['TIMESTAMP']=crazy['TIMESTAMP'].str[4:]





# for 
#     df.iloc[[2],[0]] = 10


# for file in filelist
#     file = 'NESTLE N.csv'
#     crazy = pd.DataFrame.from_csv(file,0,',')
#     str(crazy.iloc[9])[7]
#     plotfile = pd.DataFrame.from_csv(file,0,';')
#     axis_x =
# Out:
# NAME
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
# NESTLE N    11
#             ..
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# NESTLE N    10
# Name: TIMESTAMP, Length: 36045, dtype: object

# %%
axis_x = crazy['TIMESTAMP']-20171000090116
axis_x
